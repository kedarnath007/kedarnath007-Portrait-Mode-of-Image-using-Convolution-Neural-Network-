# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image 
from PIL import ImageFilter

# %%
pic_name = "999"
in1 = Image.open(pic_name+".jpg")
gt1 = Image.open(pic_name+"_seg.png")

# %%
def create_image(i, j):
  image = Image.new("RGB", (i, j), "white")
  return image
width,height = gt1.size
new = create_image(width, height)
pixels = new.load()

# %%
height = height - 1
width = width - 1
test1 = in1

# %%
for i in range(width):
    for j in range(height):
        r,g,b = gt1.getpixel((i,j))
        if r == 0 and g == 0 and b == 0:
            # pixel = in1.getpixel((i,j))
            pixels[i,j] = in1.getpixel((i,j))
        else:
            pixels[i,j] = in1.getpixel((i,j))

# %%
new
# Out:
# <PIL.Image.Image image mode=RGB size=400x267 at 0x1912601B710>

# %%
blurred_image = new.filter(ImageFilter.GaussianBlur(radius=3))
new1 = create_image(width, height)
pixelss = new1.load()

# %%
blurred_image
# Out:
# <PIL.Image.Image image mode=RGB size=400x267 at 0x1912601BE10>

# %%
for i in range(width):
    for j in range(height):
        r,g,b = gt1.getpixel((i,j))
        if r == 0 and g == 0 and b == 0:
            pixelss[i,j] = blurred_image.getpixel((i,j))
        else:
            pixelss[i,j] = in1.getpixel((i,j))

# %%
new1.save("./"+pic_name+"_blur.png")
